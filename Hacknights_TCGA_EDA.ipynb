# %% [markdown]
# # Exploratory Data Analysis of Cancer Genomics data using TCGA
#
# In this notebook, we will take a look at one of the canonical datasets, if not _the_ dataset, in cancer genomics: TCGA.
#
# We'll start with investigating the RNA Sequencing (rnaseq) and Clinical data available for the cancer type LIHC.
#
# The data is stored in the R package _[RTCGA](http://rtcga.github.io/RTCGA/)_

# %% [markdown]
# ## Load libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Set variables

# %%
data_dir="data/"
response_name="patient.race"
rnaseq_file=data_dir+"lihc_rnaseq.csv.gz"
clinical_file=data_dir+"lihc_clinical.csv.gz"

# %% [markdown]
# ## Load data

# %% [markdown]
# The data is stored in the RTCGA package in the R programming language. I've outputted it for easy use within python.
#
# We will be investigating the Hepatocellular carcinoma dataset. Read about it [here](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5680778/).
#
# The TCGA RNASeq data is illumina hiseq Level 3 RSEM normalized expression data. You can read about thec RSEM method [here](https://academic.oup.com/bioinformatics/article/26/4/493/243395).
#
# Essentially this is the raw counts of reads that aligned to the gene transcript, though it's only a guess by the program. Since it's a guess, the values are rational numbers. To simplify things, we'll round the values to the next whole integer.

# %%
rnaseq = (pd.
          read_csv(rnaseq_file,compression="gzip").
          set_index('bcr_patient_barcode').
          applymap(lambda x : int(np.ceil(x)))
         )
display(rnaseq.shape)
display(rnaseq.head())
# Out:
# (423, 20531)
#                               ?|100130426  ?|100133144  ?|100134869  ?|10357  \
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07            0            2            4       91
# TCGA-2Y-A9GS-01A-12R-A38B-07            0           27            3       72
# TCGA-2Y-A9GT-01A-11R-A38B-07            0            0            5       96
# TCGA-2Y-A9GU-01A-11R-A38B-07            0            6            6       62
# TCGA-2Y-A9GV-01A-11R-A38B-07            0           12            6      105
#
#                               ?|10431  ?|136542  ?|155060  ?|26823  ?|280660  \
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07     1018         0       142        1         0
# TCGA-2Y-A9GS-01A-12R-A38B-07      640         0       123        2         0
# TCGA-2Y-A9GT-01A-11R-A38B-07      743         0        96        2         1
# TCGA-2Y-A9GU-01A-11R-A38B-07     1187         0       281        1         0
# TCGA-2Y-A9GV-01A-11R-A38B-07      879         0       283        0         0
#
#                               ?|317712  ...  ZXDA|7789  ZXDB|158586  \
# bcr_patient_barcode                     ...
# TCGA-2V-A95S-01A-11R-A37K-07         0  ...         25          274
# TCGA-2Y-A9GS-01A-12R-A38B-07         0  ...         69          633
# TCGA-2Y-A9GT-01A-11R-A38B-07         0  ...         47         1220
# TCGA-2Y-A9GU-01A-11R-A38B-07         0  ...         19          286
# TCGA-2Y-A9GV-01A-11R-A38B-07         0  ...         42         1000
#
#                               ZXDC|79364  ZYG11A|440590  ZYG11B|79699  \
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07         795             19           500
# TCGA-2Y-A9GS-01A-12R-A38B-07        1154             72          1001
# TCGA-2Y-A9GT-01A-11R-A38B-07        1134             13          1290
# TCGA-2Y-A9GU-01A-11R-A38B-07        1151             10           942
# TCGA-2Y-A9GV-01A-11R-A38B-07        1632              5          1381
#
#                               ZYX|7791  ZZEF1|23140  ZZZ3|26009  \
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07      3173          891         511
# TCGA-2Y-A9GS-01A-12R-A38B-07      5302          756         861
# TCGA-2Y-A9GT-01A-11R-A38B-07      3220          861         524
# TCGA-2Y-A9GU-01A-11R-A38B-07      3093         1340         344
# TCGA-2Y-A9GV-01A-11R-A38B-07      2903          576         666
#
#                               psiTPTE22|387590  tAKR|389932
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07                 4            7
# TCGA-2Y-A9GS-01A-12R-A38B-07                 7          483
# TCGA-2Y-A9GT-01A-11R-A38B-07                15           84
# TCGA-2Y-A9GU-01A-11R-A38B-07                 3            3
# TCGA-2Y-A9GV-01A-11R-A38B-07                 3          120
#
# [5 rows x 20531 columns]

# %%
gene_name_logical = [len(x[0])>1 for x in rnaseq.columns.str.split('|')]
sub = rnaseq.loc[:,gene_name_logical]
sub.columns = [x[0] for x in sub.columns.str.split('|')]
rnaseq_sub = sub.copy()
rnaseq_sub.head()
# Out:
#                                A1BG  A1CF  A2BP1  A2LD1  A2ML1     A2M  \
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07  22283   584      0    375      0  286320
# TCGA-2Y-A9GS-01A-12R-A38B-07  22642  1573      3     99      0   31169
# TCGA-2Y-A9GT-01A-11R-A38B-07  77670  1281      0    215      1   19515
# TCGA-2Y-A9GU-01A-11R-A38B-07   9323  1253      0   2914      2  243941
# TCGA-2Y-A9GV-01A-11R-A38B-07  84243  1641      0    404      0    8756
#
#                               A4GALT  A4GNT  AAA1  AAAS  ...  ZXDA  ZXDB  \
# bcr_patient_barcode                                      ...
# TCGA-2V-A95S-01A-11R-A37K-07      81    543     1  1032  ...    25   274
# TCGA-2Y-A9GS-01A-12R-A38B-07     163      2     1   903  ...    69   633
# TCGA-2Y-A9GT-01A-11R-A38B-07     119      1     3   773  ...    47  1220
# TCGA-2Y-A9GU-01A-11R-A38B-07      72      0     0   722  ...    19   286
# TCGA-2Y-A9GV-01A-11R-A38B-07      83      0     9   828  ...    42  1000
#
#                               ZXDC  ZYG11A  ZYG11B   ZYX  ZZEF1  ZZZ3  \
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07   795      19     500  3173    891   511
# TCGA-2Y-A9GS-01A-12R-A38B-07  1154      72    1001  5302    756   861
# TCGA-2Y-A9GT-01A-11R-A38B-07  1134      13    1290  3220    861   524
# TCGA-2Y-A9GU-01A-11R-A38B-07  1151      10     942  3093   1340   344
# TCGA-2Y-A9GV-01A-11R-A38B-07  1632       5    1381  2903    576   666
#
#                               psiTPTE22  tAKR
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07          4     7
# TCGA-2Y-A9GS-01A-12R-A38B-07          7   483
# TCGA-2Y-A9GT-01A-11R-A38B-07         15    84
# TCGA-2Y-A9GU-01A-11R-A38B-07          3     3
# TCGA-2Y-A9GV-01A-11R-A38B-07          3   120
#
# [5 rows x 20501 columns]

# %% [markdown]
# The clinical data is within the RTCGA package, but is also available [here](https://portal.gdc.cancer.gov/projects/TCGA-LIHC). More cdescription of the clinical attributes are [here](https://gdc.cancer.gov/about-data/data-harmonization-and-generation/clinical-data-harmonization).

# %%
clinical = pd.read_csv(clinical_file,compression="gzip").set_index('patient.bcr_patient_barcode')
display(clinical.shape)
display(clinical.head())
# Out:
# (377, 1586)
#                                                   admin.bcr  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                 nationwide children's hospital
# tcga-2y-a9gs                 nationwide children's hospital
# tcga-2y-a9gt                 nationwide children's hospital
# tcga-2y-a9gu                 nationwide children's hospital
# tcga-2y-a9gv                 nationwide children's hospital
#
#                              admin.day_of_dcc_upload admin.disease_code  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                       1               lihc
# tcga-2y-a9gs                                       1               lihc
# tcga-2y-a9gt                                       1               lihc
# tcga-2y-a9gu                                       1               lihc
# tcga-2y-a9gv                                       1               lihc
#
#                                                   admin.file_uuid  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                 47a9da83-f87b-45a0-a501-542c5a9df212
# tcga-2y-a9gs                 ada84bc2-9724-428c-9557-7280af5f8297
# tcga-2y-a9gt                 b9f63d47-2293-4360-b373-5acdaa2ec7cb
# tcga-2y-a9gu                 2b488ba2-f46b-4d0b-8c73-d9a761ab61b1
# tcga-2y-a9gv                 69fc70f4-fe6a-472a-b354-cf37515c524d
#
#                              admin.month_of_dcc_upload  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                        10
# tcga-2y-a9gs                                        10
# tcga-2y-a9gt                                        10
# tcga-2y-a9gu                                        10
# tcga-2y-a9gv                                        10
#
#                              admin.patient_withdrawal.withdrawn  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                              False
# tcga-2y-a9gs                                              False
# tcga-2y-a9gt                                              False
# tcga-2y-a9gu                                              False
# tcga-2y-a9gv                                              False
#
#                             admin.project_code  admin.year_of_dcc_upload  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                              tcga                      2015
# tcga-2y-a9gs                              tcga                      2015
# tcga-2y-a9gt                              tcga                      2015
# tcga-2y-a9gu                              tcga                      2015
# tcga-2y-a9gv                              tcga                      2015
#
#                             patient.ablation_embolization_tx_adjuvant  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                                       no
# tcga-2y-a9gs                                                       no
# tcga-2y-a9gt                                                      NaN
# tcga-2y-a9gu                                                       no
# tcga-2y-a9gv                                                       no
#
#                              patient.additional_studies  ...  \
# patient.bcr_patient_barcode                              ...
# tcga-2v-a95s                                        NaN  ...
# tcga-2y-a9gs                                        NaN  ...
# tcga-2y-a9gt                                        NaN  ...
# tcga-2y-a9gu                                        NaN  ...
# tcga-2y-a9gv                                        NaN  ...
#
#                             patient.samples.sample.preservation_method  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                                       NaN
# tcga-2y-a9gs                                                       NaN
# tcga-2y-a9gt                                                       NaN
# tcga-2y-a9gu                                                       NaN
# tcga-2y-a9gv                                                       NaN
#
#                              patient.samples.sample.sample_type  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                      primary tumor
# tcga-2y-a9gs                                      primary tumor
# tcga-2y-a9gt                                      primary tumor
# tcga-2y-a9gu                                      primary tumor
# tcga-2y-a9gv                                      primary tumor
#
#                             patient.samples.sample.sample_type_id  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                                    1
# tcga-2y-a9gs                                                    1
# tcga-2y-a9gt                                                    1
# tcga-2y-a9gu                                                    1
# tcga-2y-a9gv                                                    1
#
#                              patient.samples.sample.shortest_dimension  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                                       NaN
# tcga-2y-a9gs                                                       NaN
# tcga-2y-a9gt                                                       NaN
# tcga-2y-a9gu                                                       NaN
# tcga-2y-a9gv                                                       NaN
#
#                             patient.samples.sample.time_between_clamping_and_freezing  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                                               NaN
# tcga-2y-a9gs                                                               NaN
# tcga-2y-a9gt                                                               NaN
# tcga-2y-a9gu                                                               NaN
# tcga-2y-a9gv                                                               NaN
#
#                              patient.samples.sample.time_between_excision_and_freezing  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                                               NaN
# tcga-2y-a9gs                                                               NaN
# tcga-2y-a9gt                                                               NaN
# tcga-2y-a9gu                                                               NaN
# tcga-2y-a9gv                                                               NaN
#
#                             patient.samples.sample.tissue_type  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                               NaN
# tcga-2y-a9gs                                               NaN
# tcga-2y-a9gt                                               NaN
# tcga-2y-a9gu                                               NaN
# tcga-2y-a9gv                                               NaN
#
#                             patient.samples.sample.tumor_descriptor  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                                    NaN
# tcga-2y-a9gs                                                    NaN
# tcga-2y-a9gt                                                    NaN
# tcga-2y-a9gu                                                    NaN
# tcga-2y-a9gv                                                    NaN
#
#                              patient.samples.sample.tumor_pathology  \
# patient.bcr_patient_barcode
# tcga-2v-a95s                                                    NaN
# tcga-2y-a9gs                                                    NaN
# tcga-2y-a9gt                                                    NaN
# tcga-2y-a9gu                                                    NaN
# tcga-2y-a9gv                                                    NaN
#
#                              patient.samples.sample.vial_number
# patient.bcr_patient_barcode
# tcga-2v-a95s                                                  a
# tcga-2y-a9gs                                                  a
# tcga-2y-a9gt                                                  a
# tcga-2y-a9gu                                                  a
# tcga-2y-a9gv                                                  a
#
# [5 rows x 1586 columns]

# %% [markdown]
# ## Gene level distribution
#
# In this section, we will investigate the value distribution of genes in our dataset.
#
# <br>
#
# Sample questions:
#
# What is the range of values for a given gene?
#
# What is the distribution of values for a given gene?
#
# Are there higher than average or lower than average expression of genes?

# %% [markdown]
# ## Dimension reduction based on gene expression
#
# In this section, we will investigate a lower dimensional gene expression space

# %% [markdown]
# ## Differential Expression Analysis
#
# In this section, we will investigate differential expression results derived from the [DESeq2] package in R. Also see this [vignette](https://bioconductor.org/packages/release/bioc/vignettes/DESeq2/inst/doc/DESeq2.html) on how to do these analyses, as well as understand the methods.

# %% [markdown]
# ## Clinical data type investigation
#
# In this section, we will investigate the diversity of the clinical data
#
# <br>
#
# Sample Questions:
#
# How many unique values are there for a given clinical attribute?
#
# How can we define an appropriate response variable for supervised learning?

# %% [markdown]
# ## Set up for supervised learning
#
# In this section, we will set up a supervised learning paradigm using the Genes within the RNASeq data as predictors and a clinical attribute as a response variable.
