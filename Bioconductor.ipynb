# %% [markdown]
# # [Open-source software for the analysis and comprehension of high-throughput genomic data](https://www.bioconductor.org/)

# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

# %%
BiocManager::install()
# Out:
# Bioconductor version 3.7 (BiocManager 1.30.4), R 3.5.0 (2018-04-23)
# Update old packages: 'bigrquery', 'cowplot', 'DatabaseConnector', 'dbparser',
#   'deldir', 'devtools', 'digest', 'dplyr', 'DT', 'FactoMineR', 'formatR',
#   'ggplot2', 'ggstance', 'haven', 'mime', 'PerformanceAnalytics', 'pillar',
#   'plotrix', 'RcppArmadillo', 'rlang', 'skimr', 'snahelper', 'tibble', 'vctrs',
#   'zip', 'anytime', 'blob', 'blogdown', 'bold', 'bookdown', 'boot',
#   'bootstrap', 'callr', 'checkmate', 'cli', 'cluster', 'coda', 'crul',
#   'data.table', 'DatabaseConnectorJars', 'dbplyr', 'ellipsis', 'fpc', 'future',
#   'future.apply', 'geometry', 'git2r', 'hms', 'httpuv', 'later', 'markdown',
#   'mclust', 'mvtnorm', 'numDeriv', 'openssl', 'pbapply', 'pbmcapply',
#   'phangorn', 'plotly', 'processx', 'purrr', 'quantreg', 'R.utils', 'R6',
#   'recipes', 'remotes', 'reticulate', 'rmarkdown', 'rngtools', 'rotl',
#   'rsample', 'rstan', 'rstudioapi', 'segmented', 'servr', 'Seurat', 'shiny',
# ...

# %% [markdown]
# ## Experimental data
#
# @ https://www.bioconductor.org/packages/release/BiocViews.html#___ExperimentData
#
# For example, we'll load single cell RNA expression data

# %%
BiocManager::install("monocle")
# Out:
# Bioconductor version 3.7 (BiocManager 1.30.4), R 3.5.0 (2018-04-23)
# Installing package(s) 'monocle'
# also installing the dependencies ‘FNN’, ‘sparsesvd’, ‘docopt’, ‘RBGL’, ‘RUnit’, ‘VGAM’, ‘DDRTree’, ‘fastICA’, ‘densityClust’, ‘qlcMatrix’, ‘biocViews’
# The downloaded binary packages are in
# 	/var/folders/j0/74wnfjb528n4qgcz2_fpzjbh0000gn/T//RtmpK3srzn/downloaded_packages
# Update old packages: 'bigrquery', 'cowplot', 'DatabaseConnector', 'dbparser',
#   'deldir', 'devtools', 'digest', 'dplyr', 'DT', 'FactoMineR', 'formatR',
#   'ggplot2', 'ggstance', 'haven', 'mime', 'PerformanceAnalytics', 'pillar',
#   'plotrix', 'RcppArmadillo', 'rlang', 'skimr', 'snahelper', 'tibble', 'vctrs',
#   'zip', 'anytime', 'blob', 'blogdown', 'bold', 'bookdown', 'boot',
#   'bootstrap', 'callr', 'checkmate', 'cli', 'cluster', 'coda', 'crul',
#   'data.table', 'DatabaseConnectorJars', 'dbplyr', 'ellipsis', 'fpc', 'future',
# ...

# %%
library(monocle)
# Out:
# Loading required package: Matrix
# Warning message:
# “package ‘Matrix’ was built under R version 3.5.2”Loading required package: Biobase
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:Matrix’:
#
#     colMeans, colSums, rowMeans, rowSums, which
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colMeans,
#     colnames, colSums, dirname, do.call, duplicated, eval, evalq,
#     Filter, Find, get, grep, grepl, intersect, is.unsorted, lapply,
# ...

# %%
hsmm=monocle::load_HSMM()

# %%
fData(hsmm)
# Out:
#                    gene_short_name biotype              num_cells_expressed
# ENSG00000000003.10 TSPAN6          protein_coding       231
# ENSG00000000005.5  TNMD            protein_coding         0
# ENSG00000000419.8  DPM1            protein_coding       275
# ENSG00000000457.8  SCYL3           protein_coding        24
# ENSG00000000460.12 C1orf112        protein_coding        78
# ENSG00000000938.8  FGR             protein_coding         0
# ENSG00000000971.11 CFH             protein_coding       252
# ENSG00000001036.8  FUCA2           protein_coding       238
# ENSG00000001084.6  GCLC            protein_coding        64
# ENSG00000001167.10 NFYA            protein_coding       124
# ENSG00000001460.13 STPG1           protein_coding        32
# ENSG00000001461.12 NIPAL3          protein_coding       132
# ENSG00000001497.12 LAS1L           protein_coding       132
# ENSG00000001561.6  ENPP4           protein_coding        45
# ...
