# %% [markdown]
# # Exploratory Data Analysis of Cancer Genomics data using TCGA
#
# In this notebook, we will take a look at one of the canonical datasets, if not _the_ dataset, in cancer genomics: TCGA.
#
# We'll start with investigating the RNA Sequencing (rnaseq) and Clinical data available for a type of liver cancer known as hepatocellular carcinoma (HCC). Hepatocellular carcinoma is the most common form of liver cancer in the United States, making up [more than 80% of cases](https://www.cancer.gov/about-nci/organization/ccg/research/structural-genomics/tcga/studied-cancers/liver). The TCGA dataset is abbreviated LIHC.
#
# Some examples of what researchers have learned from the LIHC dataset at the DNA-level include confirmed [frequent mutations](https://www.cancer.gov/about-nci/organization/ccg/research/structural-genomics/tcga/studied-cancers/liver) in:
#  - The TERT promotor region, associated with regulating cell survival
#  - TP53, one of the most frequently mutated genes in cancer
#  - CTNNB1, a member of the Wnt signaling pathway that mediates cell growth and differentiation
#
# There are currently several therapies under development that target these genes.
#
# In addition to DNA alterations however, different biological and tumor microenvrionment factors can [influence disease progression](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6237857/). A transcriptomic survey of tissues at various stages of disease progression could help elucidate some of the underlying pathways contributing to tumorigenesis.
#
# ### Today, we'll be focusing on using RNA-seq data from LIHC combined with clinical attributes to identify biomarkers for disease progression.
#
# The data is stored in the R package _[RTCGA](http://rtcga.github.io/RTCGA/)_

# %% [markdown]
# ## Load libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/mattheweng/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /Users/mattheweng/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /Users/mattheweng/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %% [markdown]
# ## Set variables

# %%
data_dir=""
response_name="patient.race"
rnaseq_file=data_dir+"lihc_rnaseq.csv.gz"
clinical_file=data_dir+"lihc_clinical.csv.gz"

# %% [markdown]
# ## Load data

# %% [markdown]
# The data is stored in the RTCGA package in the R programming language. I've outputted it for easy use within python.
#
# We will be investigating the Hepatocellular carcinoma dataset. Read about it [here](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5680778/).
#
# The TCGA RNASeq data is illumina hiseq Level 3 RSEM normalized expression data. You can read about thec RSEM method [here](https://academic.oup.com/bioinformatics/article/26/4/493/243395).
#
# Essentially this is the raw counts of reads that aligned to the gene transcript, though it's only a guess by the program. Since it's a guess, the values are rational numbers. To simplify things, we'll round the values to the next whole integer.
#
# We will be using clinical data from the [GDC Data portal](https://portal.gdc.cancer.gov/projects/TCGA-LIHC).

# %%
rnaseq = (pd.
          read_csv(rnaseq_file,compression="gzip").
          set_index('bcr_patient_barcode').
          applymap(lambda x : int(np.ceil(x)))
         )
display(rnaseq.shape)
display(rnaseq.head())
# Out:
# (423, 20531)
#                               ?|100130426  ?|100133144  ?|100134869  ?|10357  \
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07            0            2            4       91
# TCGA-2Y-A9GS-01A-12R-A38B-07            0           27            3       72
# TCGA-2Y-A9GT-01A-11R-A38B-07            0            0            5       96
# TCGA-2Y-A9GU-01A-11R-A38B-07            0            6            6       62
# TCGA-2Y-A9GV-01A-11R-A38B-07            0           12            6      105
#
#                               ?|10431  ?|136542  ?|155060  ?|26823  ?|280660  \
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07     1018         0       142        1         0
# TCGA-2Y-A9GS-01A-12R-A38B-07      640         0       123        2         0
# TCGA-2Y-A9GT-01A-11R-A38B-07      743         0        96        2         1
# TCGA-2Y-A9GU-01A-11R-A38B-07     1187         0       281        1         0
# TCGA-2Y-A9GV-01A-11R-A38B-07      879         0       283        0         0
#
#                               ?|317712  ...  ZXDA|7789  ZXDB|158586  \
# bcr_patient_barcode                     ...
# TCGA-2V-A95S-01A-11R-A37K-07         0  ...         25          274
# TCGA-2Y-A9GS-01A-12R-A38B-07         0  ...         69          633
# TCGA-2Y-A9GT-01A-11R-A38B-07         0  ...         47         1220
# TCGA-2Y-A9GU-01A-11R-A38B-07         0  ...         19          286
# TCGA-2Y-A9GV-01A-11R-A38B-07         0  ...         42         1000
#
#                               ZXDC|79364  ZYG11A|440590  ZYG11B|79699  \
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07         795             19           500
# TCGA-2Y-A9GS-01A-12R-A38B-07        1154             72          1001
# TCGA-2Y-A9GT-01A-11R-A38B-07        1134             13          1290
# TCGA-2Y-A9GU-01A-11R-A38B-07        1151             10           942
# TCGA-2Y-A9GV-01A-11R-A38B-07        1632              5          1381
#
#                               ZYX|7791  ZZEF1|23140  ZZZ3|26009  \
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07      3173          891         511
# TCGA-2Y-A9GS-01A-12R-A38B-07      5302          756         861
# TCGA-2Y-A9GT-01A-11R-A38B-07      3220          861         524
# TCGA-2Y-A9GU-01A-11R-A38B-07      3093         1340         344
# TCGA-2Y-A9GV-01A-11R-A38B-07      2903          576         666
#
#                               psiTPTE22|387590  tAKR|389932
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07                 4            7
# TCGA-2Y-A9GS-01A-12R-A38B-07                 7          483
# TCGA-2Y-A9GT-01A-11R-A38B-07                15           84
# TCGA-2Y-A9GU-01A-11R-A38B-07                 3            3
# TCGA-2Y-A9GV-01A-11R-A38B-07                 3          120
#
# [5 rows x 20531 columns]

# %%
gene_name_logical = [len(x[0])>1 for x in rnaseq.columns.str.split('|')]
sub = rnaseq.loc[:,gene_name_logical]
sub.columns = [x[0] for x in sub.columns.str.split('|')]
rnaseq_sub = sub.copy()
rnaseq_sub.head()
# Out:
#                                A1BG  A1CF  A2BP1  A2LD1  A2ML1     A2M  \
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07  22283   584      0    375      0  286320
# TCGA-2Y-A9GS-01A-12R-A38B-07  22642  1573      3     99      0   31169
# TCGA-2Y-A9GT-01A-11R-A38B-07  77670  1281      0    215      1   19515
# TCGA-2Y-A9GU-01A-11R-A38B-07   9323  1253      0   2914      2  243941
# TCGA-2Y-A9GV-01A-11R-A38B-07  84243  1641      0    404      0    8756
#
#                               A4GALT  A4GNT  AAA1  AAAS  ...  ZXDA  ZXDB  \
# bcr_patient_barcode                                      ...
# TCGA-2V-A95S-01A-11R-A37K-07      81    543     1  1032  ...    25   274
# TCGA-2Y-A9GS-01A-12R-A38B-07     163      2     1   903  ...    69   633
# TCGA-2Y-A9GT-01A-11R-A38B-07     119      1     3   773  ...    47  1220
# TCGA-2Y-A9GU-01A-11R-A38B-07      72      0     0   722  ...    19   286
# TCGA-2Y-A9GV-01A-11R-A38B-07      83      0     9   828  ...    42  1000
#
#                               ZXDC  ZYG11A  ZYG11B   ZYX  ZZEF1  ZZZ3  \
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07   795      19     500  3173    891   511
# TCGA-2Y-A9GS-01A-12R-A38B-07  1154      72    1001  5302    756   861
# TCGA-2Y-A9GT-01A-11R-A38B-07  1134      13    1290  3220    861   524
# TCGA-2Y-A9GU-01A-11R-A38B-07  1151      10     942  3093   1340   344
# TCGA-2Y-A9GV-01A-11R-A38B-07  1632       5    1381  2903    576   666
#
#                               psiTPTE22  tAKR
# bcr_patient_barcode
# TCGA-2V-A95S-01A-11R-A37K-07          4     7
# TCGA-2Y-A9GS-01A-12R-A38B-07          7   483
# TCGA-2Y-A9GT-01A-11R-A38B-07         15    84
# TCGA-2Y-A9GU-01A-11R-A38B-07          3     3
# TCGA-2Y-A9GV-01A-11R-A38B-07          3   120
#
# [5 rows x 20501 columns]

# %% [markdown]
# The clinical data is within the RTCGA package, but is also available [here](https://portal.gdc.cancer.gov/projects/TCGA-LIHC). More cdescription of the clinical attributes are [here](https://gdc.cancer.gov/about-data/data-harmonization-and-generation/clinical-data-harmonization).

# %%
clinical = pd.read_csv('clinical.tsv', sep='\t')
clinical['submitter_id'] = clinical['submitter_id'].map(lambda x: x.lower())
clinical.head()
# Out:
#                                 case_id  submitter_id project_id  gender  \
# 0  bce25281-502e-4599-9679-32dc8462ffb1  tcga-dd-a4ne  TCGA-LIHC  female
# 1  654af137-70d9-4ee4-9f69-793e352d30f8  tcga-dd-a1ee  TCGA-LIHC    male
# 2  45f00f00-d793-4dca-aeb9-7626d4575c90  tcga-gj-a9db  TCGA-LIHC    male
# 3  496beef9-80d9-4734-a23d-334ae1b6aaab  tcga-dd-aac8  TCGA-LIHC    male
# 4  d1aa9c1a-d732-48c0-b669-8a14e0397344  tcga-2y-a9gv  TCGA-LIHC  female
#
#   year_of_birth   race days_to_birth               ethnicity vital_status  \
# 0          1936  white        -27549      hispanic or latino         Dead
# 1          1933  white        -26858  not hispanic or latino         Dead
# 2          1945  white        -25020  not hispanic or latino         Dead
# 3          1936  asian        -26322  not hispanic or latino         Dead
# 4          1953  white        -20011  not hispanic or latino         Dead
#
#   days_to_death  ... treatment_effect initial_disease_status  \
# 0           660  ...               --                     --
# 1           349  ...               --                     --
# 2            67  ...               --                     --
# 3            16  ...               --                     --
# 4          2532  ...               --                     --
#
#                 treatment_type therapeutic_agents regimen_or_line_of_therapy  \
# 0  Pharmaceutical Therapy, NOS                 --                         --
# 1  Pharmaceutical Therapy, NOS                 --                         --
# 2  Pharmaceutical Therapy, NOS                 --                         --
# 3  Pharmaceutical Therapy, NOS                 --                         --
# 4  Pharmaceutical Therapy, NOS                 --                         --
#
#   treatment_intent_type treatment_anatomic_site treatment_outcome  \
# 0                    --                      --                --
# 1                    --                      --                --
# 2                    --                      --                --
# 3                    --                      --                --
# 4                    --                      --                --
#
#   days_to_treatment_end treatment_or_therapy
# 0                    --                   no
# 1                    --                   no
# 2                    --                   no
# 3                    --                   no
# 4                    --                  yes
#
# [5 rows x 47 columns]

# %%
rnaseq_sub.index = rnaseq_sub.index.map(lambda x: '-'.join(x.split('-')[:3]).lower())
rnaseq_sub.head()
# Out:
#                       A1BG  A1CF  A2BP1  A2LD1  A2ML1     A2M  A4GALT  A4GNT  \
# bcr_patient_barcode
# tcga-2v-a95s         22283   584      0    375      0  286320      81    543
# tcga-2y-a9gs         22642  1573      3     99      0   31169     163      2
# tcga-2y-a9gt         77670  1281      0    215      1   19515     119      1
# tcga-2y-a9gu          9323  1253      0   2914      2  243941      72      0
# tcga-2y-a9gv         84243  1641      0    404      0    8756      83      0
#
#                      AAA1  AAAS  ...  ZXDA  ZXDB  ZXDC  ZYG11A  ZYG11B   ZYX  \
# bcr_patient_barcode              ...
# tcga-2v-a95s            1  1032  ...    25   274   795      19     500  3173
# tcga-2y-a9gs            1   903  ...    69   633  1154      72    1001  5302
# tcga-2y-a9gt            3   773  ...    47  1220  1134      13    1290  3220
# tcga-2y-a9gu            0   722  ...    19   286  1151      10     942  3093
# tcga-2y-a9gv            9   828  ...    42  1000  1632       5    1381  2903
#
#                      ZZEF1  ZZZ3  psiTPTE22  tAKR
# bcr_patient_barcode
# tcga-2v-a95s           891   511          4     7
# tcga-2y-a9gs           756   861          7   483
# tcga-2y-a9gt           861   524         15    84
# tcga-2y-a9gu          1340   344          3     3
# tcga-2y-a9gv           576   666          3   120
#
# [5 rows x 20501 columns]

# %%
rnaseq_sub.reset_index()
# Out:
#     bcr_patient_barcode    A1BG  A1CF  A2BP1  A2LD1  A2ML1     A2M  A4GALT  \
# 0          tcga-2v-a95s   22283   584      0    375      0  286320      81
# 1          tcga-2y-a9gs   22642  1573      3     99      0   31169     163
# 2          tcga-2y-a9gt   77670  1281      0    215      1   19515     119
# 3          tcga-2y-a9gu    9323  1253      0   2914      2  243941      72
# 4          tcga-2y-a9gv   84243  1641      0    404      0    8756      83
# ..                  ...     ...   ...    ...    ...    ...     ...     ...
# 418        tcga-zs-a9cd   66433  1296      0    259      0   72358     641
# 419        tcga-zs-a9ce  159666  2266      2    498      0   19481      39
# 420        tcga-zs-a9cf   14369  1577      0    322      1   29739     408
# 421        tcga-zs-a9cf    6034  1552      0    380      2   37332      76
# 422        tcga-zs-a9cg   18746  2379      0    262      0   10622     234
#
#      A4GNT  AAA1  ...  ZXDA  ZXDB  ZXDC  ZYG11A  ZYG11B   ZYX  ZZEF1  ZZZ3  \
# 0      543     1  ...    25   274   795      19     500  3173    891   511
# 1        2     1  ...    69   633  1154      72    1001  5302    756   861
# 2        1     3  ...    47  1220  1134      13    1290  3220    861   524
# 3        0     0  ...    19   286  1151      10     942  3093   1340   344
# 4        0     9  ...    42  1000  1632       5    1381  2903    576   666
# ..     ...   ...  ...   ...   ...   ...     ...     ...   ...    ...   ...
# 418      0     0  ...    31  1254   774       8    1239  4029    636   435
# 419      0     2  ...    34   249   976      29     883  4042    492   578
# 420      1    20  ...    56  1333  1459      56    1258  1173    432   837
# 421      2    15  ...    47   901  1222     112    1218   612    894   925
# 422      0     0  ...    35   238   857      90    2053  1964    630   623
#
#      psiTPTE22  tAKR
# 0            4     7
# 1            7   483
# 2           15    84
# 3            3     3
# 4            3   120
# ..         ...   ...
# 418          7   197
# 419          0   125
# 420          3   125
# 421          4    60
# 422          6   113
#
# [423 rows x 20502 columns]

# %%
full_df = pd.merge(rnaseq_sub.reset_index(), clinical[['submitter_id','tumor_stage']], left_on='bcr_patient_barcode', right_on='submitter_id', how='inner') \
    .set_index('bcr_patient_barcode') \
    .drop('submitter_id', axis=1)
full_df.head()
# Out:
#                       A1BG  A1CF  A2BP1  A2LD1  A2ML1     A2M  A4GALT  A4GNT  \
# bcr_patient_barcode
# tcga-2v-a95s         22283   584      0    375      0  286320      81    543
# tcga-2y-a9gs         22642  1573      3     99      0   31169     163      2
# tcga-2y-a9gt         77670  1281      0    215      1   19515     119      1
# tcga-2y-a9gu          9323  1253      0   2914      2  243941      72      0
# tcga-2y-a9gv         84243  1641      0    404      0    8756      83      0
#
#                      AAA1  AAAS  ...  ZXDB  ZXDC  ZYG11A  ZYG11B   ZYX  ZZEF1  \
# bcr_patient_barcode              ...
# tcga-2v-a95s            1  1032  ...   274   795      19     500  3173    891
# tcga-2y-a9gs            1   903  ...   633  1154      72    1001  5302    756
# tcga-2y-a9gt            3   773  ...  1220  1134      13    1290  3220    861
# tcga-2y-a9gu            0   722  ...   286  1151      10     942  3093   1340
# tcga-2y-a9gv            9   828  ...  1000  1632       5    1381  2903    576
#
#                      ZZZ3  psiTPTE22  tAKR   tumor_stage
# bcr_patient_barcode
# tcga-2v-a95s          511          4     7        8170/3
# tcga-2y-a9gs          861          7   483  not reported
# tcga-2y-a9gt          524         15    84       stage i
# tcga-2y-a9gu          344          3     3         20187
# tcga-2y-a9gv          666          3   120       stage i
#
# [5 rows x 20502 columns]

# %%
tumor_stages = clinical['tumor_stage'].value_counts()
plt.hist(tumor_stages.values)
# Out:
# (array([248.,   0.,   0.,   1.,   0.,   1.,   0.,   1.,   0.,   1.]),
#  array([ 1. ,  5.2,  9.4, 13.6, 17.8, 22. , 26.2, 30.4, 34.6, 38.8, 43. ]),
#  <a list of 10 Patch objects>)

# %%
tumor_stages
# Out:
# stage i         43
# stage iiia      34
# stage ii        25
# not reported    14
# stage iiic       5
#                 ..
# 20586            1
# 26465            1
# 21606            1
# 25096            1
# 24185            1
# Name: tumor_stage, Length: 252, dtype: int64

# %%
# Subset out the recognizable stages
tumor_stages[tumor_stages.index.str.startswith('stage')]
# Out:
# stage i       43
# stage iiia    34
# stage ii      25
# stage iiic     5
# stage iiib     4
# stage ivb      2
# stage iii      2
# stage iv       1
# Name: tumor_stage, dtype: int64

# %%
# Subset full dataframe for patient samples that have a corresponding tumor stage
full_df = full_df.loc[full_df['tumor_stage'].str.startswith('stage')]

# Since there are substages (eg, stage iia and stage iib), we will conver them to the 4 main stages
full_df['tumor_stage'] = full_df['tumor_stage'].str.replace('stage ', '') \
                            .str.replace('a', '') \
                            .str.replace('b', '') \
                            .str.replace('c', '') \
                            .str.replace('v', '')
full_df
# Out:
#                       A1BG  A1CF  A2BP1  A2LD1  A2ML1     A2M  A4GALT  A4GNT  \
# bcr_patient_barcode
# tcga-2y-a9gt         77670  1281      0    215      1   19515     119      1
# tcga-2y-a9gv         84243  1641      0    404      0    8756      83      0
# tcga-2y-a9gw         73056  1423      0    270      0   43813     299      0
# tcga-2y-a9gy         23352  1559      0    104      2   11699      42      2
# tcga-2y-a9gz         43942  2033      1    963      0  264407      97      1
# ...                    ...   ...    ...    ...    ...     ...     ...    ...
# tcga-ub-a7mf         13195   641      0    493      0  110307     169      0
# tcga-wx-aa47           689   763      0    199      0   67703     830      0
# tcga-xr-a8tf         62514  3612      0    306      0    3302      62      0
# tcga-ya-a8s7          2675   441      0     62      1   75528    1053      3
# tcga-zs-a9cd         66433  1296      0    259      0   72358     641      0
#
#                      AAA1  AAAS  ...  ZXDB  ZXDC  ZYG11A  ZYG11B    ZYX  \
# bcr_patient_barcode              ...
# tcga-2y-a9gt            3   773  ...  1220  1134      13    1290   3220
# tcga-2y-a9gv            9   828  ...  1000  1632       5    1381   2903
# tcga-2y-a9gw            1   622  ...  1647   707      30     748   8467
# tcga-2y-a9gy            3  1179  ...   166   996     129     486   3825
# tcga-2y-a9gz            0   919  ...   444  1318     128    1550   1394
# ...                   ...   ...  ...   ...   ...     ...     ...    ...
# tcga-ub-a7mf            1   999  ...   307  1222      30     638   3961
# tcga-wx-aa47            0  1075  ...   295   750      91     647    811
# tcga-xr-a8tf            0  1152  ...   777  1293     184    1291    945
# tcga-ya-a8s7            0   812  ...   427   707      56     639  10911
# tcga-zs-a9cd            0   586  ...  1254   774       8    1239   4029
#
#                      ZZEF1  ZZZ3  psiTPTE22  tAKR  tumor_stage
# bcr_patient_barcode
# tcga-2y-a9gt           861   524         15    84      stage i
# tcga-2y-a9gv           576   666          3   120      stage i
# tcga-2y-a9gw           993   457          7   103      stage i
# tcga-2y-a9gy           458   471         14     1     stage ii
# tcga-2y-a9gz           712   976          5   271     stage ii
# ...                    ...   ...        ...   ...          ...
# tcga-ub-a7mf           918   465          5     0   stage iiia
# tcga-wx-aa47          1198   442          2    26   stage iiia
# tcga-xr-a8tf           814   871          2    29      stage i
# tcga-ya-a8s7           800   699          3     3   stage iiia
# tcga-zs-a9cd           636   435          7   197     stage ii
#
# [139 rows x 20502 columns]

# %% [markdown]
# # Pre-process
# With ~20k features, we can reduce the feature set in a number of ways:
# - Removing lowly expressed genes (one way we can define this as less than 1 copy of a gene per person)
# - Subsetting the genes that show the most variation between samples
# - Using genes known to be associated with the hallmarks of cancer
#
# Using all or some of these techniques, reduce the number of features from our dataset. A dictionary with genes from the hallmarks of cancer can be loaded as follows:

# %%
import pickle

descr_dict = pickle.load(open('../../hallmarks_of_cancer_description_dictionary.pkl','rb'))
geneset_dict = pickle.load(open('../../hallmarks_of_cancer_geneset_dictionary.pkl','rb'))

# %% [markdown]
# As high dimensionality can be problematic for certain machine learning models, another method for reducing the feature space is to perform dimension reduction. A technique known as [sparse principal component analysis](https://bmcbioinformatics.biomedcentral.com/articles/10.1186/s12859-019-2929-8) (SPCA). SPCA is a varition on the widely-used principle component analysis (PCA), that uses lasso to produce principle components with sparse loadings and make more interpretable components.
#
# Try to further reduce the dimensional space using SPCA We can start with 10 components.

# %%
from sklearn.decomposition import MiniBatchSparsePCA
from sklearn.manifold import TSNE

# %% [markdown]
# ## Semi-supervised clustering of patient samples

# %%
from sklearn.semi_supervised import LabelPropagation, LabelSpreading

# %% [markdown]
# ## Supervised learning for tumor stage imputation
#
# We'll be investigating how gene expression varies based on tumor stage. We can subset and filter out any lowly-expressed genes, genes that haven't been identified as being significant within the [Hallmarks of Cancer](http://software.broadinstitute.org/gsea/msigdb/search.jsp), and genes that have shown high variation within our samples.
#
# Let's start by generating a Random Forest model, since we're interested in the gene signature that may be responsible for progressing tumor stage.
#
# An example of how models can be used to identify genes of interest can be found in [Wenrick and Shemirani, 2018](https://www.frontiersin.org/articles/10.3389/fgene.2018.00297/full) and [Rendleman et al, 2019](https://bmcbioinformatics.biomedcentral.com/articles/10.1186/s12859-019-2929-8)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
